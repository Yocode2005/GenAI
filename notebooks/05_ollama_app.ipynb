# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gemma4:31b-cloud")

# %%
res = llm.invoke("Hello, I am yogesh")
res.content
# Out:
# "Hello Yogesh! It's nice to meet you. How can I help you today?"
